# %% [markdown]
# ## Data Preprocessing to get Final Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
#loading dataset
credits_df=pd.read_csv("credits.csv")
titles_df=pd.read_csv("titles.csv")

print(f"The credits data has {credits_df.shape[0]} rows and {credits_df.shape[1]} columns")
print(f"The titles data has {titles_df.shape[0]} rows and {titles_df.shape[1]} columns")
# Out:
# The credits data has 77213 rows and 5 columns
# The titles data has 5806 rows and 15 columns

# %%
credits_df.sample(5)
# Out:
#        person_id        id              name       character   role
# 18366      21334  tm181270  Jodi Lyn O'Keefe  Chelle Ringell  ACTOR
# 56875    1562362  tm925785     Mauricio Aspe             NaN  ACTOR
# 41595    1185475  tm411503    Antonia Gentry             NaN  ACTOR
# 49380     282177  tm460124        Alisha Boe            Nina  ACTOR
# 42807     870491  tm372061       Hikmathulla      Journalist  ACTOR

# %%
titles_df.sample(5)
# Out:
#              id                     title   type  \
# 2604   tm233484           Duck Duck Goose  MOVIE
# 1112   tm149747  The Perfect Dictatorship  MOVIE
# 3233   tm453862                  The Call  MOVIE
# 1971    ts86169          The Innocent Man   SHOW
# 5668  tm1024062                   Nayattu  MOVIE
#
#                                             description  release_year  \
# 2604  After he’s grounded by an injury, a high-flyin...          2018
# 1112  TV MX, the most powerful Mexican Television Co...          2014
# 3233  Connected by phone in the same home but 20 yea...          2020
# 1971  In a story that gained national attention with...          2018
# 5668  Three police officers are forced to go on the ...          2021
#
#      age_certification  runtime  \
# 2604                PG       82
# 1112               NaN      143
# 3233               NaN      112
# 1971             TV-MA       47
# 5668               NaN      124
#
#                                                  genres production_countries  \
# 2604                  ['comedy', 'family', 'animation']               ['CN']
# 1112                                ['comedy', 'drama']               ['MX']
# 3233  ['thriller', 'scifi', 'drama', 'crime', 'horror']               ['KR']
# 1971                         ['documentation', 'crime']               ['US']
# 5668                     ['drama', 'thriller', 'crime']               ['IN']
#
#       seasons     imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 2604      NaN   tt4940416         5.7      3686.0           17.258         6.2
# 1112      NaN   tt3970854         7.2      5370.0           10.475         7.3
# 3233      NaN  tt10530176         7.1     29450.0           34.559         7.6
# 1971      1.0   tt0914376         7.3      5883.0            7.434         7.0
# 5668      NaN  tt11604676         8.1      6780.0            4.151         7.6

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# Visually asessing the credits data , we can see it contains different actor and director names for the same id
#
# So I will be removing duplicates based on this id so that it will be easier to merge

# %%
credits_df['id'].duplicated().sum()
# Out:
# 71779

# %%
len(credits_df.drop_duplicates(subset='id'))
# Out:
# 5434

# %%
new_credits_df=credits_df[['id','name']].drop_duplicates(subset='id')

# %%
new_credits_df.sample(5)
# Out:
#               id                 name
# 38292   tm312767        Katy Townsend
# 38626   tm314829  Penelope Ann Miller
# 73707   ts297065       Miryam Lumpini
# 60743   tm475162            Hong Chau
# 69182  tm1107225          Clara Galle

# %%
#merging the titles and new credits data together
final_df=pd.merge(titles_df,new_credits_df ,on='id')

# %%
final_df.sample(5)
# Out:
#              id                                title   type  \
# 382     tm31189            The Spiderwick Chronicles  MOVIE
# 3842   tm470378  ReMastered: Devil at the Crossroads  MOVIE
# 1812   tm266666                        Gerald's Game  MOVIE
# 783    tm177958                   Pyaar Ka Punchnama  MOVIE
# 4637  tm1022103                              Outlaws  MOVIE
#
#                                             description  release_year  \
# 382   Upon moving into the run-down Spiderwick Estat...          2008
# 3842  Robert Johnson was one of the most influential...          2019
# 1812  When her husband's sex game goes wrong, Jessie...          2017
# 783   Nishant starts dating Charu while his roommate...          2011
# 4637  Introverted Girona student Nacho meets two del...          2021
#
#      age_certification  runtime  \
# 382                 PG       96
# 3842               NaN       48
# 1812               NaN      103
# 783              PG-13      149
# 4637                 R      125
#
#                                                  genres production_countries  \
# 382   ['fantasy', 'thriller', 'action', 'drama', 'fa...               ['US']
# 3842                         ['documentation', 'music']               ['US']
# 1812                    ['horror', 'thriller', 'drama']               ['US']
# 783          ['romance', 'comedy', 'drama', 'european']               ['IN']
# 4637                    ['crime', 'thriller', 'action']               ['ES']
#
#       seasons     imdb_id  imdb_score  imdb_votes  tmdb_popularity  \
# 382       NaN   tt0416236         6.5     94628.0           30.838
# 3842      NaN   tt9046574         7.0      2691.0            7.171
# 1812      NaN   tt3748172         6.5    104894.0           19.167
# 783       NaN   tt1926313         7.7     21204.0            5.152
# 4637      NaN  tt11892272         6.9      3722.0           96.602
#
#       tmdb_score            name
# 382          6.6    Sarah Bolger
# 3842         6.9  Keith Richards
# 1812         6.4    Carla Gugino
# 783          7.0       Esen Işık
# 4637         7.0     Marcos Ruiz

# %%
print(f"The final merged data has {final_df.shape[0]} rows and {final_df.shape[1]} columns")
# Out:
# The final merged data has 5434 rows and 16 columns

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5434 entries, 0 to 5433
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    5434 non-null   object
#  1   title                 5433 non-null   object
#  2   type                  5434 non-null   object
#  3   description           5424 non-null   object
#  4   release_year          5434 non-null   int64
#  5   age_certification     2951 non-null   object
#  6   runtime               5434 non-null   int64
#  7   genres                5434 non-null   object
#  8   production_countries  5434 non-null   object
#  9   seasons               1776 non-null   float64
#  10  imdb_id               5024 non-null   object
#  11  imdb_score            4963 non-null   float64
#  12  imdb_votes            4949 non-null   float64
#  13  tmdb_popularity       5432 non-null   float64
#  14  tmdb_score            5259 non-null   float64
#  15  name                  5434 non-null   object
# dtypes: float64(5), int64(2), object(9)
# memory usage: 721.7+ KB

# %% [markdown]
# ##changing series to dataframe and saving in folder
#
# gen_series=final_df['genres'].apply(eval).explode().value_counts()
# pd.DataFrame(gen_series).rename(columns={'Unnamed: 0':'genre','genres':'counts'}).to_csv('gen.csv')
#
# pdt_series=final_df['production_countries'].apply(eval).explode().value_counts()
# pd.DataFrame(pdt_series).rename(columns={'Unnamed: 0':'production_countries','production_countries':'counts'}).to_csv('pdt.csv')

# %%
#checking for nulls 
null=[]
col_=[]
null_per=[]
dict={}
for col in final_df.columns:
    null_count=final_df[col].isnull().sum()
    
    if null_count>0:
        col_.append(col)
        null.append(null_count)
        nullpercent=(round(null_count*100/len(final_df)))
        null_per.append(nullpercent)
        dict['column']=col_
        dict['null_count']=null
        dict['null_percent(%)']=null_per
        null_df=pd.DataFrame(dict)
        #print(col,null_count ,str(round(null_count*100/len(final_df)))+ "%" )

null_df
# Out:
#               column  null_count  null_percent(%)
# 0              title           1                0
# 1        description          10                0
# 2  age_certification        2483               46
# 3            seasons        3658               67
# 4            imdb_id         410                8
# 5         imdb_score         471                9
# 6         imdb_votes         485                9
# 7    tmdb_popularity           2                0
# 8         tmdb_score         175                3

# %% [markdown]
# In this section, we will be reviewing the columns with missing values with the end goal being to remove nulls from the dataset

# %%
final_df.query("type == 'MOVIE'").shape[0]
# Out:
# 3658

# %%
#checking each column to check for source of nulls
final_df.query("type == 'MOVIE'").seasons.isnull().sum()*100/final_df.query("type == 'MOVIE'").shape[0]
# Out:
# 100.0

# %% [markdown]
# All movies in the dataset had 100% nulls in the seasons column which is expected as movies tended to not be seasonal
#
# We will be filling missing values with 0 instead of dropping them.

# %%
final_df['seasons']=final_df['seasons'].fillna(0)

# %%
#filling nulls in the age certification column with NR which means Not Rated
final_df['age_certification']=final_df['age_certification'].fillna("NR")

# %%
final_df.drop(columns=['imdb_id'],inplace=True)

# %% [markdown]
# Filling missing numerical columns with the mean

# %%
cols=['imdb_score','imdb_votes','tmdb_popularity','tmdb_score']
for col in cols:
    mean=final_df[col].mean().round(2)
    final_df[col]=final_df[col].fillna(mean)

# %% [markdown]
# Filling the remaining missing values with empty string

# %%
final_df=final_df.fillna('')

# %%
final_df.duplicated().sum()
# Out:
# 0

# %%
print(f"The final cleaned data has {final_df.shape[0]} rows and {final_df.shape[1]} columns")
# Out:
# The final cleaned data has 5434 rows and 15 columns

# %%
#cleaning the genres and production companies column 
def clean(col):
    new_column=[]

    for line in final_df[col]:
        cols=str(line).replace("['",'').replace("']",'').replace("'",'').replace(',','').strip()
        new_column.append(cols)

    final_df[col]=new_column

# %%
clean('genres')
clean('production_countries')

# %%
final_df.sample(5)
# Out:
#             id                           title   type  \
# 2739  tm285712  Jen Kirkman: Just Keep Livin'?  MOVIE
# 930   tm165521                      Redemption  MOVIE
# 307    tm94606                       Let Me In  MOVIE
# 3382  tm948128                          Audrey  MOVIE
# 3728  tm502151               A Remarkable Tale  MOVIE
#
#                                             description  release_year  \
# 2739  Incisive comic Jen Kirkman gets real about wom...          2017
# 930   Homeless and on the run from a military court ...          2013
# 307   A bullied young boy befriends a young female v...          2010
# 3382  An intimate look at Audrey Hepburn's life, wit...          2020
# 3728  A town at the edge of the missing take despera...          2019
#
#      age_certification  runtime                                  genres  \
# 2739                NR       69                                  comedy
# 930                  R      100                thriller action european
# 307                  R      116  horror drama fantasy thriller european
# 3382                PG      100                   documentation history
# 3728                PG       93                   comedy drama european
#
#      production_countries  seasons  imdb_score  imdb_votes  tmdb_popularity  \
# 2739                   US      0.0        6.70     1281.00            3.985
# 930                 US GB      0.0        6.53    24675.55           59.493
# 307                 GB US      0.0        7.10   120208.00           24.490
# 3382                CH US      0.0        7.10     1867.00            6.316
# 3728                   ES      0.0        5.30     1159.00            5.253
#
#       tmdb_score              name
# 2739         6.6       Jen Kirkman
# 930          6.2     Jason Statham
# 307          6.8  Kodi Smit-McPhee
# 3382         7.1    Audrey Hepburn
# 3728         5.7      Carmen Machi

# %%
final_df.describe()
# Out:
#        release_year      runtime      seasons   imdb_score    imdb_votes  \
# count   5434.000000  5434.000000  5434.000000  5434.000000  5.434000e+03
# mean    2015.929886    79.869157     0.730217     6.528051  2.467555e+04
# std        7.410901    38.979547     1.894051     1.101597  8.530978e+04
# min     1953.000000     0.000000     0.000000     1.500000  5.000000e+00
# 25%     2015.000000    46.000000     0.000000     5.900000  7.160000e+02
# 50%     2018.000000    87.000000     0.000000     6.530000  3.320500e+03
# 75%     2020.000000   106.000000     1.000000     7.300000  2.150850e+04
# max     2022.000000   251.000000    42.000000     9.500000  2.268288e+06
#
#        tmdb_popularity   tmdb_score
# count      5434.000000  5434.000000
# mean         23.344594     6.792427
# std          70.400573     1.119633
# min           0.600000     1.000000
# 25%           3.331250     6.100000
# 50%           7.861000     6.800000
# 75%          18.571250     7.500000
# max        1823.374000    10.000000

# %%
#creating a copy of data to prepare for recommendeer system
model_df=final_df.copy()

# %%
model_df.sample(5)
# Out:
#             id            title   type  \
# 3692  ts250800     Kissing Game   SHOW
# 3721  tm319139            Saaho  MOVIE
# 1212   ts42687         PJ Masks   SHOW
# 2880  tm445258  Marriage Palace  MOVIE
# 2923  tm450512    Pinky Memsaab  MOVIE
#
#                                             description  release_year  \
# 3692  At a high school in a rural, isolated ranching...          2020
# 3721  A battle for power ensues as warring gangters ...          2019
# 1212  Connor, Greg and Amaya are normal kids by day,...          2015
# 2880  Marriage Palace is a comedy movie which takes ...          2018
# 2923  The lives of a gullible maid; a beautiful soci...          2018
#
#      age_certification  runtime  \
# 3692                NR       40
# 3721                 R      171
# 1212              TV-G       15
# 2880                NR      102
# 2923                NR      124
#
#                                               genres production_countries  \
# 3692                                           drama                   BR
# 3721             thriller action crime drama romance                   IN
# 1212  animation family fantasy scifi action european                   GB
# 2880                                          comedy                   XX
# 2923                                    drama family                   PK
#
#       seasons  imdb_score  imdb_votes  tmdb_popularity  tmdb_score  \
# 3692      1.0        6.53    24675.55           45.216         7.1
# 3721      0.0        5.50    18554.00            5.566         6.2
# 1212      5.0        5.40     1214.00           54.603         4.9
# 2880      0.0        6.20      180.00            1.400         7.0
# 2923      0.0        6.30      521.00            1.235         9.0
#
#                name
# 3692    Iza Moreira
# 3721        Prabhas
# 1212  Jacob Ewaniuk
# 2880    Sharry Maan
# 2923    Hajra Yamin

# %%
#applying title case to the title column
model_df['title']=model_df['title'].apply(lambda x:x.title())

# %%
#creating a column that combines important features 

model_df['tags']=model_df['genres'] + " " +model_df['description']+ ' '+ model_df['production_countries'] + " " +model_df['type']+" " +model_df['age_certification']+ ' '+ model_df['name']

# %%
import pandas as pd
df=pd.read_csv('final_data.csv').sort_values(by=['title'])
# Out:
#              id                            title   type  \
# 0       tm84618                      Taxi Driver  MOVIE
# 1      tm127384  Monty Python And The Holy Grail  MOVIE
# 2       tm70993                    Life Of Brian  MOVIE
# 3      tm190788                     The Exorcist  MOVIE
# 4       ts22164     Monty Python'S Flying Circus   SHOW
# ...         ...                              ...    ...
# 5429  tm1040816      Momshies! Your Soul Is Mine  MOVIE
# 5430  tm1014599                        Fine Wine  MOVIE
# 5431  tm1108171                   Edis Starlight  MOVIE
# 5432  tm1045018                            Clash  MOVIE
# 5433  tm1098060                   Shadow Parties  MOVIE
#
#                                             description  release_year  \
# 0     A mentally unstable Vietnam War veteran works ...          1976
# 1     King Arthur, accompanied by his squire, recrui...          1975
# 2     Brian Cohen is an average young Jewish man, bu...          1979
# 3     12-year-old Regan MacNeil begins to adapt an e...          1973
# 4     A British sketch comedy series with the shows ...          1969
# ...                                                 ...           ...
# 5429  Three women with totally different lives accid...          2021
# 5430  A beautiful love story that can happen between...          2021
# 5431  Rising star Edis's career journey with ups and...          2021
# 5432  A man from Nigeria returns to his family in Ca...          2021
# 5433  A family faces destruction in a long-running c...          2021
#
#      age_certification  runtime               genres production_countries  \
# 0                    R      113          crime drama                   US
# 1                   PG       91       comedy fantasy                   GB
# 2                    R       94               comedy                   GB
# 3                    R      133               horror                   US
# 4                TV-14       30      comedy european                   GB
# ...                ...      ...                  ...                  ...
# 5429                NR      108               comedy                   PH
# 5430                NR      100        romance drama                   NG
# 5431                NR       74  music documentation                   []
# 5432                NR       88         family drama                NG CA
# 5433                NR      116      action thriller                   []
#
#       seasons  imdb_score  imdb_votes  tmdb_popularity  tmdb_score  \
# 0         0.0        8.30   795222.00           27.612        8.20
# 1         0.0        8.20   530877.00           18.216        7.80
# 2         0.0        8.00   392419.00           17.505        7.80
# 3         0.0        8.10   391942.00           95.337        7.70
# 4         4.0        8.80    72895.00           12.919        8.30
# ...       ...         ...         ...              ...         ...
# 5429      0.0        5.80       26.00            4.112        6.79
# 5430      0.0        6.90       39.00            0.966        6.79
# 5431      0.0        6.53    24675.55            1.036        8.50
# 5432      0.0        6.50       32.00            0.709        6.79
# 5433      0.0        6.20        9.00            2.186        6.79
#
#                      name                                               tags
# 0          Robert De Niro  crime drama A mentally unstable Vietnam War ve...
# 1          Graham Chapman  comedy fantasy King Arthur, accompanied by his...
# 2          Graham Chapman  comedy Brian Cohen is an average young Jewish ...
# 3           Ellen Burstyn  horror 12-year-old Regan MacNeil begins to ada...
# 4          Graham Chapman  comedy european A British sketch comedy series...
# ...                   ...                                                ...
# 5429     Jolina Magdangal  comedy Three women with totally different live...
# 5430  Richard Mofe-Damijo  romance drama A beautiful love story that can ...
# 5431         Edis Görgülü  music documentation Rising star Edis's career ...
# 5432          Omoni Oboli  family drama A man from Nigeria returns to his...
# 5433          Jide Kosoko  action thriller A family faces destruction in ...
#
# [5434 rows x 16 columns]
